# %%
import pandas as ps
from matplotlib import pylab as plt

# %% [markdown]
# ### pandas & matplotlib

# %%
x=[1,2,3]
y=[3,2,1]
plt.plot(x,y)
plt.show()

# %%
z = [3,3,3]
plt.plot(x,z)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### read csv data

# %%
data=ps.read_csv('~/Downloads/countries.csv')
china = data[data.country=='China']
plt.plot(china.year,china.population)
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
smds = ps.read_csv('~/Downloads/SMDS职场数据.csv',encoding='gbk')
print('The number of that status is N is {}'.format(len(smds[smds.STATUS=='N'])))
# Out:
# The number of that status is N is 18745
